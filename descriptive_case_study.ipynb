# %%
import pandas as pd

# %% [markdown]
# ### Matplotlib and Seaborn are libraries used for visualization i.e charts

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set_style('darkgrid')
sns.set(font_scale=1.5)

# %%
# Read in TN middle school dataset from GitHub
df = pd.read_csv('https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Essential%20Statistics/middle_tn_schools.csv')

df.head(2)
# Out:
#                           name  school_rating   size  reduced_lunch  \
# 0  Allendale Elementary School            5.0  851.0           10.0
# 1          Anderson Elementary            2.0  412.0           71.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio school_type  \
# 0                 90.2                 95.8             15.7      Public
# 1                 32.8                 37.3             12.8      Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# 0          89.4          85.2                54.0            2.9
# 1          43.0          38.3                32.0            3.9
#
#    percent_white  percent_asian  percent_hispanic
# 0           85.5            1.6               5.6
# 1           86.7            1.0               4.9

# %%
df.columns
# Out:
# Index(['name', 'school_rating', 'size', 'reduced_lunch', 'state_percentile_16',
#        'state_percentile_15', 'stu_teach_ratio', 'school_type', 'avg_score_15',
#        'avg_score_16', 'full_time_teachers', 'percent_black', 'percent_white',
#        'percent_asian', 'percent_hispanic'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 15 columns):
# name                   347 non-null object
# school_rating          347 non-null float64
# size                   347 non-null float64
# reduced_lunch          347 non-null float64
# state_percentile_16    347 non-null float64
# state_percentile_15    341 non-null float64
# stu_teach_ratio        347 non-null float64
# school_type            347 non-null object
# avg_score_15           341 non-null float64
# avg_score_16           347 non-null float64
# full_time_teachers     347 non-null float64
# percent_black          347 non-null float64
# percent_white          347 non-null float64
# percent_asian          347 non-null float64
# percent_hispanic       347 non-null float64
# dtypes: float64(13), object(2)
# memory usage: 40.7+ KB

# %%
df.describe()
# Out:
#        school_rating         size  reduced_lunch  state_percentile_16  \
# count     347.000000   347.000000     347.000000           347.000000
# mean        2.968300   699.472622      50.279539            58.801729
# std         1.690377   400.598636      25.480236            32.540747
# min         0.000000    53.000000       2.000000             0.200000
# 25%         2.000000   420.500000      30.000000            30.950000
# 50%         3.000000   595.000000      51.000000            66.400000
# 75%         4.000000   851.000000      71.500000            88.000000
# max         5.000000  2314.000000      98.000000            99.800000
#
#        state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# count           341.000000       347.000000    341.000000    347.000000
# mean             58.249267        15.461671     57.004692     57.049856
# std              32.702630         5.725170     26.696450     27.968974
# ...

# %%
sr_rl = df[['reduced_lunch', 'school_rating']]

# %%
sr_rl_cat = sr_rl.groupby('school_rating')

# %%
sr_rl_cat.describe()
# Out:
#               reduced_lunch                                                  \
#                       count       mean        std   min    25%   50%    75%
# school_rating
# 0.0                    43.0  83.581395   8.813498  53.0  79.50  86.0  90.00
# 1.0                    40.0  74.950000  11.644191  53.0  65.00  74.5  84.25
# 2.0                    44.0  64.272727  11.956051  37.0  54.75  62.5  74.00
# 3.0                    56.0  50.285714  13.550866  24.0  41.00  48.5  63.00
# 4.0                    86.0  41.000000  16.681092   4.0  30.00  41.5  50.00
# 5.0                    78.0  21.602564  17.651268   2.0   8.00  19.0  29.75
#
#
#                 max
# school_rating
# 0.0            98.0
# 1.0            98.0
# 2.0            88.0
# 3.0            78.0
# 4.0            87.0
# 5.0            87.0

# %%
sr_rl.corr()
# Out:
#                reduced_lunch  school_rating
# reduced_lunch       1.000000      -0.815757
# school_rating      -0.815757       1.000000

# %% [markdown]
# ### Describe the data graphically

# %%
fig, ax = plt.subplots(figsize=(14,8))
ax.set_ylabel('School Rating')
sr_rl.boxplot(by='school_rating', ax=ax, vert=False)

# %% [markdown]
# __In her box-and-whisker plots, Sally sees that the minimum and maximum reduced_lunch values tend to get closer to the mean as school_rating decreases; that is, as school_rating decreases so does the standard deviation in reduced_lunch.__

# %% [markdown]
# What does this mean?
#
#
#
# Starting with the top box-and-whisker plot, as school_rating decreases, reduced_lunchbecomes a more powerful way to explain outcomes.
#
#
#
# This could be because as parents' incomes decrease they have fewer resources to devote to their children's education (such as, after-school programs, tutors, time spent on homework, computer camps, etc) than higher-income parents.

# %%
plt.figure(figsize=(14,8)) # set the size of the graph
_ = sns.regplot(data=sr_rl, x='reduced_lunch', y='school_rating')
# Out:
# C:\Users\edwin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
cor = df.corr()

# %%
cor.columns.values
# Out:
# array(['school_rating', 'size', 'reduced_lunch', 'state_percentile_16',
#        'state_percentile_15', 'stu_teach_ratio', 'avg_score_15',
#        'avg_score_16', 'full_time_teachers', 'percent_black',
#        'percent_white', 'percent_asian', 'percent_hispanic'], dtype=object)

# %%
_, ax = plt.subplots(figsize=(50,23))
_ = sns.heatmap(cor, ax=ax,
                xticklabels=cor.columns.values,
                yticklabels=cor.columns.values,
                cmap='coolwarm')

# %%
df.columns
# Out:
# Index(['name', 'school_rating', 'size', 'reduced_lunch', 'state_percentile_16',
#        'state_percentile_15', 'stu_teach_ratio', 'school_type', 'avg_score_15',
#        'avg_score_16', 'full_time_teachers', 'percent_black', 'percent_white',
#        'percent_asian', 'percent_hispanic'],
#       dtype='object')

# %%
rc_sr = df[['percent_white','percent_hispanic','percent_black','percent_asian','school_rating']]

# %%
type(rc_sr.corr())
# Out:
# pandas.core.frame.DataFrame

# %%
rc_sr_corr = rc_sr.corr()
rc_sr_corr
# Out:
#                   percent_white  percent_hispanic  percent_black  \
# percent_white          1.000000         -0.537571      -0.874202
# percent_hispanic      -0.537571          1.000000       0.086627
# percent_black         -0.874202          0.086627       1.000000
# percent_asian         -0.092287          0.187277      -0.112274
# school_rating          0.639014         -0.376288      -0.593869
#
#                   percent_asian  school_rating
# percent_white         -0.092287       0.639014
# percent_hispanic       0.187277      -0.376288
# percent_black         -0.112274      -0.593869
# percent_asian          1.000000       0.161469
# school_rating          0.161469       1.000000

# %%
_, ax = plt.subplots(figsize=(17,10))
_ = sns.heatmap(rc_sr_corr, ax=ax,
                xticklabels=rc_sr_corr.columns.values,
                yticklabels=rc_sr_corr.columns.values,
                cmap='coolwarm')

# %% [markdown]
# ### The hypothesis is:
#
# __H0: There is a negative relationship between reduced lunch and school rating__ <br>
# __H1: There is NO negative relationship between reduced lunch and school rating__
